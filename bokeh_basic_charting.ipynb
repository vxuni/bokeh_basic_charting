# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
eth_price = pd.read_html('https://coinmarketcap.com/currencies/ethereum/historical-data/', 'Market Cap', parse_dates=[0])[0]
eth_price.head()
# Out:
#         Date   Open*    High     Low  Close**      Volume   Market Cap
# 0 2018-09-12  185.42  185.59  170.26   183.33  1874850000  18894773430
# 1 2018-09-11  198.18  198.51  180.60   185.07  1568900000  20190354865
# 2 2018-09-10  197.85  201.88  189.58   197.08  1502960000  20153125179
# 3 2018-09-09  198.38  207.67  188.31   196.92  1585980000  20203492382
# 4 2018-09-08  217.91  220.37  193.26   197.95  1517200000  22187693065

# %%
eth_price.rename({'Open*': 'Open', 'Close**': 'Close', 'Market Cap': 'Market_Cap'}, axis='columns', inplace=True)

# %%
from bokeh.io import output_notebook, show

output_notebook()

import bokeh_basic_charting as bbc

p = bbc.make_candlesticks(eth_price)

show(p)  # open a browser
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="38503a1b-e83d-4882-85a4-b74a133a7ce1">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e0018d4f-391a-43d9-bae0-8d64aed6e6f7"></div>

# %%
p = bbc.make_candlesticks_cs(eth_price)
show(p)
# Out:
#   <div class="bk-root" id="3aea5704-1582-4df3-b65e-a54e96c51571"></div>

# %%
p.document.to_json()

# %%
# make new figure; bokeh figures should not be reused like this, and deepcopy errors out.
p2 = bbc.make_candlesticks(eth_price)
p2 = bbc.add_volume_bars(eth_price, p2)
show(p2)
# Out:
#   <div class="bk-root" id="9a6818bc-230b-479c-b20c-876936d15e26"></div>

# %%
pg = bbc.make_linked_candlesticks_and_volume(eth_price)
show(pg)
# Out:
#   <div class="bk-root" id="080cbfe2-7b27-4e36-85ce-5023e3af8603"></div>

# %% [markdown]
# # Notes
#
# * bokeh's use of function wrappers and `*args, **kwargs` to define their API calls makes life harder for the IDE. Try to see docs of glyph calls, or jump to definition of Figure.
#     * discoverability is much lower compared to altair
#     * the online docs (which are quite good) will have to be consulted more often
